# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="rar9aNIyoLwed5KLnJBE")
project = rf.workspace("konstantin-arfm1").project("bfmc-ynbzk-it9dm")
version = project.version(2)
dataset = version.download("yolov8-obb")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 22.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 85.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 136.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to BFMC-2 in yolov8-obb:: 100%|██████████| 31374/31374 [00:03<00:00, 10097.84it/s]

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 27.5 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# Loading model
model = YOLO('yolov8n.pt')

# Start training...
# 'data.yaml' - there are parameters of model (epochs, etc..)
results = model.train(data='/content/BFMC-2/data.yaml', epochs=50, imgsz=256)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.240 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt source=/content/bfmc2020_online_3.avi conf=0.5 imgsz=256 save=True
# Out:
# Ultralytics 8.3.240 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,008,183 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (frame 1/2056) /content/bfmc2020_online_3.avi: 192x256 (no detections), 38.1ms
# video 1/1 (frame 2/2056) /content/bfmc2020_online_3.avi: 192x256 (no detections), 9.3ms
# video 1/1 (frame 3/2056) /content/bfmc2020_online_3.avi: 192x256 (no detections), 6.9ms
# video 1/1 (frame 4/2056) /content/bfmc2020_online_3.avi: 192x256 (no detections), 6.3ms
# video 1/1 (frame 5/2056) /content/bfmc2020_online_3.avi: 192x256 (no detections), 6.9ms
# video 1/1 (frame 6/2056) /content/bfmc2020_online_3.avi: 192x256 (no detections), 6.5ms
# video 1/1 (frame 7/2056) /content/bfmc2020_online_3.avi: 192x256 (no detections), 9.4ms
# video 1/1 (frame 8/2056) /content/bfmc2020_online_3.avi: 192x256 (no detections), 6.7ms
# video 1/1 (frame 9/2056) /content/bfmc2020_online_3.avi: 192x256 (no detections), 6.9ms
# ...
